# %%
import pandas as pd

# %%
# 1. Importați fișierul CSV folosind Pandas și afișați primele 5 rânduri. 

df = pd.read_csv("clwin.csv", index_col="id")
df.head()
# Out:
#     country        team  trophies
# id
# 0   England   Liverpool       6.0
# 1     Spain   Barcelona       5.0
# 2   England  Man United       3.0
# 3     Italy       Inter       3.0
# 4   England     Chelsea       2.0

# %%
# 2. Afișați tipurile de date ale fiecărei coloane. 
df.dtypes
# Out:
# country      object
# team         object
# trophies    float64
# dtype: object

# %%
# 3. Obțineți statisticile rezumate ale coloanelor numerice din date. 
df.describe()
# Out:
#         trophies
# count  19.000000
# mean    2.000000
# std     1.414214
# min     1.000000
# 25%     1.000000
# 50%     2.000000
# 75%     2.000000
# max     6.000000

# %%
df.count()
# Out:
# country     20
# team        20
# trophies    19
# dtype: int64

# %%
df.min()
# Out:
# country         England
# team        Aston Villa
# trophies            1.0
# dtype: object

# %%
# 4. Verificați dacă există valori lipsă în setul de date. 
df.isna().sum()
# Out:
# country     0
# team        0
# trophies    1
# dtype: int64

# %%
df[df["trophies"].isna()]
# Out:
#     country  team  trophies
# id
# 17  Romania  FCSB       NaN

# %%
# 5. Numărați câte echipe se află în total
df["country"].count()
# Out:
# np.int64(20)

# %%
# 6. Selectați și afișați coloanele „echipă” și „trofee”. 
df.keys()
# Out:
# Index(['country', 'team', 'trophies'], dtype='object')

# %%
df[ ["team", "trophies"] ].head(2)
# Out:
#          team  trophies
# id
# 0   Liverpool       6.0
# 1   Barcelona       5.0

# %%
df[ ["team", "trophies"] ].rename(columns={"team":"echipa", "trophies":"trofee"})
# Out:
#            echipa  trofee
# id
# 0       Liverpool     6.0
# 1       Barcelona     5.0
# 2      Man United     3.0
# 3           Inter     3.0
# 4         Chelsea     2.0
# 5         Chelsea     2.0
# 6    Nottm Forest     2.0
# 7         Benfica     2.0
# 8        Juventus     2.0
# 9        FC Porto     2.0
# 10       Man City     1.0
# 11       Dortmund     1.0
# 12      Feyenoord     1.0
# 13      Marseille     1.0
# 14    Aston Villa     1.0
# 15        Hamburg     1.0
# 16  Crvena zvezda     1.0
# 17           FCSB     NaN
# 18            PSV     1.0
# 19         Celtic     1.0

# %%
# 7. Selectați rândurile în care țara este „Anglia”. 

df[df["country"] == "England"]
# Out:
#     country          team  trophies
# id
# 0   England     Liverpool       6.0
# 2   England    Man United       3.0
# 4   England       Chelsea       2.0
# 5   England       Chelsea       2.0
# 6   England  Nottm Forest       2.0
# 10  England      Man City       1.0
# 14  England   Aston Villa       1.0

# %%
# 8. Afișează rândurile în care „trofeele” sunt mai mari decât 2. 
cel_putin_2_trofee = df["trophies"] > 2
df[cel_putin_2_trofee]
# Out:
#     country        team  trophies
# id
# 0   England   Liverpool       6.0
# 1     Spain   Barcelona       5.0
# 2   England  Man United       3.0
# 3     Italy       Inter       3.0

# %%
# 9. Accesați coloanele „echipă” și „țară” pentru primele 10 rânduri. 
df[["team", "country"]].head(10)
# Out:
#             team   country
# id
# 0      Liverpool   England
# 1      Barcelona     Spain
# 2     Man United   England
# 3          Inter     Italy
# 4        Chelsea   England
# 5        Chelsea   England
# 6   Nottm Forest   England
# 7        Benfica  Portugal
# 8       Juventus     Italy
# 9       FC Porto  Portugal

# %%
df[["team", "country"]][:10]
# Out:
#             team   country
# id
# 0      Liverpool   England
# 1      Barcelona     Spain
# 2     Man United   England
# 3          Inter     Italy
# 4        Chelsea   England
# 5        Chelsea   England
# 6   Nottm Forest   England
# 7        Benfica  Portugal
# 8       Juventus     Italy
# 9       FC Porto  Portugal

# %% [markdown]
# # iloc -> indexlocation

# %%
df[["team", "country"]].iloc[:10]
# Out:
#             team   country
# id
# 0      Liverpool   England
# 1      Barcelona     Spain
# 2     Man United   England
# 3          Inter     Italy
# 4        Chelsea   England
# 5        Chelsea   England
# 6   Nottm Forest   England
# 7        Benfica  Portugal
# 8       Juventus     Italy
# 9       FC Porto  Portugal

# %%
# 10. Selectați ultimele 5 rânduri ale DataFrame. 
df.tail()
# Out:
#         country           team  trophies
# id
# 15      Germany        Hamburg       1.0
# 16       Serbia  Crvena zvezda       1.0
# 17      Romania           FCSB       NaN
# 18  Netherlands            PSV       1.0
# 19     Scotland         Celtic       1.0

# %%
df[-5:]
# Out:
#         country           team  trophies
# id
# 15      Germany        Hamburg       1.0
# 16       Serbia  Crvena zvezda       1.0
# 17      Romania           FCSB       NaN
# 18  Netherlands            PSV       1.0
# 19     Scotland         Celtic       1.0

# %%
df.iloc[-5:]
# Out:
#         country           team  trophies
# id
# 15      Germany        Hamburg       1.0
# 16       Serbia  Crvena zvezda       1.0
# 17      Romania           FCSB       NaN
# 18  Netherlands            PSV       1.0
# 19     Scotland         Celtic       1.0

# %%
# 11. Filtrați echipele din „Spania” și afișați-le datele. 

df["country"].unique()
# Out:
# array(['England', 'Spain', 'Italy', 'Portugal', 'Germany', 'Netherlands',
#        'France', 'Serbia', 'Romania', 'Scotland'], dtype=object)

# %%
df[df["country"] == "Spain"]
# Out:
#    country       team  trophies
# id
# 1    Spain  Barcelona       5.0

# %%
df
# Out:
#         country           team  trophies
# id
# 0       England      Liverpool       6.0
# 1         Spain      Barcelona       5.0
# 2       England     Man United       3.0
# 3         Italy          Inter       3.0
# 4       England        Chelsea       2.0
# 5       England        Chelsea       2.0
# 6       England   Nottm Forest       2.0
# 7      Portugal        Benfica       2.0
# 8         Italy       Juventus       2.0
# 9      Portugal       FC Porto       2.0
# 10      England       Man City       1.0
# 11      Germany       Dortmund       1.0
# 12  Netherlands      Feyenoord       1.0
# 13       France      Marseille       1.0
# 14      England    Aston Villa       1.0
# 15      Germany        Hamburg       1.0
# 16       Serbia  Crvena zvezda       1.0
# 17      Romania           FCSB       NaN
# 18  Netherlands            PSV       1.0
# 19     Scotland         Celtic       1.0

# %% [markdown]
# # Adaugarea unei noi intrari in pandas

# %%
df.loc[20] = ["Spain", "Real Madrid", 15]
df
# Out:
#         country           team  trophies
# id
# 0       England      Liverpool       6.0
# 1         Spain      Barcelona       5.0
# 2       England     Man United       3.0
# 3         Italy          Inter       3.0
# 4       England        Chelsea       2.0
# 5       England        Chelsea       2.0
# 6       England   Nottm Forest       2.0
# 7      Portugal        Benfica       2.0
# 8         Italy       Juventus       2.0
# 9      Portugal       FC Porto       2.0
# 10      England       Man City       1.0
# 11      Germany       Dortmund       1.0
# 12  Netherlands      Feyenoord       1.0
# 13       France      Marseille       1.0
# 14      England    Aston Villa       1.0
# 15      Germany        Hamburg       1.0
# 16       Serbia  Crvena zvezda       1.0
# 17      Romania           FCSB       NaN
# 18  Netherlands            PSV       1.0
# 19     Scotland         Celtic       1.0
# 20        Spain    Real Madrid      15.0

# %% [markdown]
# # Sortare dupa o anumita coloana

# %%
df = df.sort_values("trophies", ascending=False) # creaza un nou dataframe
df
# Out:
#         country           team  trophies
# id
# 20        Spain    Real Madrid      15.0
# 0       England      Liverpool       6.0
# 1         Spain      Barcelona       5.0
# 2       England     Man United       3.0
# 3         Italy          Inter       3.0
# 4       England        Chelsea       2.0
# 5       England        Chelsea       2.0
# 6       England   Nottm Forest       2.0
# 7      Portugal        Benfica       2.0
# 8         Italy       Juventus       2.0
# 9      Portugal       FC Porto       2.0
# 15      Germany        Hamburg       1.0
# 19     Scotland         Celtic       1.0
# 18  Netherlands            PSV       1.0
# 16       Serbia  Crvena zvezda       1.0
# 11      Germany       Dortmund       1.0
# 14      England    Aston Villa       1.0
# 13       France      Marseille       1.0
# 12  Netherlands      Feyenoord       1.0
# 10      England       Man City       1.0
# 17      Romania           FCSB       NaN

# %% [markdown]
# # Reindexare

# %%
df.reset_index().head(2)
# Out:
#    id  country         team  trophies
# 0  20    Spain  Real Madrid      15.0
# 1   0  England    Liverpool       6.0

# %% [markdown]
# # Reindexare cu renuntarea la vechiul index (drop)

# %%
df = df.reset_index(drop=True)
df.head(3)
# Out:
#    country         team  trophies
# 0    Spain  Real Madrid      15.0
# 1  England    Liverpool       6.0
# 2    Spain    Barcelona       5.0

# %% [markdown]
# # Verificarea valorilor duplicate

# %%
df[df.duplicated()]
# Out:
#    country     team  trophies
# 6  England  Chelsea       2.0

# %%
df.iloc[5:7]
# Out:
#    country     team  trophies
# 5  England  Chelsea       2.0
# 6  England  Chelsea       2.0

# %% [markdown]
# # Eliminarea valorilor duplicate

# %%
df = df.drop_duplicates()
df
# Out:
#         country           team  trophies
# 0         Spain    Real Madrid      15.0
# 1       England      Liverpool       6.0
# 2         Spain      Barcelona       5.0
# 3       England     Man United       3.0
# 4         Italy          Inter       3.0
# 5       England        Chelsea       2.0
# 7       England   Nottm Forest       2.0
# 8      Portugal        Benfica       2.0
# 9         Italy       Juventus       2.0
# 10     Portugal       FC Porto       2.0
# 11      Germany        Hamburg       1.0
# 12     Scotland         Celtic       1.0
# 13  Netherlands            PSV       1.0
# 14       Serbia  Crvena zvezda       1.0
# 15      Germany       Dortmund       1.0
# 16      England    Aston Villa       1.0
# 17       France      Marseille       1.0
# 18  Netherlands      Feyenoord       1.0
# 19      England       Man City       1.0
# 20      Romania           FCSB       NaN

# %% [markdown]
# # Reindexare cu renuntarea la vechiul index (drop)

# %%
df.reset_index(drop=True) # Aici se creeaza un nou dataframe
# Out:
#         country           team  trophies
# 0         Spain    Real Madrid      15.0
# 1       England      Liverpool       6.0
# 2         Spain      Barcelona       5.0
# 3       England     Man United       3.0
# 4         Italy          Inter       3.0
# 5       England        Chelsea       2.0
# 6       England   Nottm Forest       2.0
# 7      Portugal        Benfica       2.0
# 8         Italy       Juventus       2.0
# 9      Portugal       FC Porto       2.0
# 10      Germany        Hamburg       1.0
# 11     Scotland         Celtic       1.0
# 12  Netherlands            PSV       1.0
# 13       Serbia  Crvena zvezda       1.0
# 14      Germany       Dortmund       1.0
# 15      England    Aston Villa       1.0
# 16       France      Marseille       1.0
# 17  Netherlands      Feyenoord       1.0
# 18      England       Man City       1.0
# 19      Romania           FCSB       NaN

# %% [markdown]
# # Reindexare IN PLACE cu renuntarea la vechiul index (drop)

# %%
df.reset_index(drop=True, inplace=True) # nu returneaza nimic, dar executa functia si o aplica DataFrame-ului

# %%
df
# Out:
#         country           team  trophies
# 0         Spain    Real Madrid      15.0
# 1       England      Liverpool       6.0
# 2         Spain      Barcelona       5.0
# 3       England     Man United       3.0
# 4         Italy          Inter       3.0
# 5       England        Chelsea       2.0
# 6       England   Nottm Forest       2.0
# 7      Portugal        Benfica       2.0
# 8         Italy       Juventus       2.0
# 9      Portugal       FC Porto       2.0
# 10      Germany        Hamburg       1.0
# 11     Scotland         Celtic       1.0
# 12  Netherlands            PSV       1.0
# 13       Serbia  Crvena zvezda       1.0
# 14      Germany       Dortmund       1.0
# 15      England    Aston Villa       1.0
# 16       France      Marseille       1.0
# 17  Netherlands      Feyenoord       1.0
# 18      England       Man City       1.0
# 19      Romania           FCSB       NaN

# %%
df.keys()
# Out:
# Index(['country', 'team', 'trophies'], dtype='object')

# %% [markdown]
# # Crearea unui DataFrame folosind liste

# %%
big_df = pd.DataFrame([["Italy", "AC Milan", 7], ["Germany", "Bayern Munchen", 6]], columns=['country', 'team', 'trophies'])
big_df
# Out:
#    country            team  trophies
# 0    Italy        AC Milan         7
# 1  Germany  Bayern Munchen         6

# %% [markdown]
# # Crearea unui DataFrame folosind dictionar

# %%
dictionar = {"country":["Italy", "Germany"], 
             "team":["AC Milan", "Bayern Munchen"],
              "trophies" :[7, 6]}


big_df = pd.DataFrame(dictionar)
big_df
# Out:
#    country            team  trophies
# 0    Italy        AC Milan         7
# 1  Germany  Bayern Munchen         6

# %% [markdown]
# # Combinare a 2 DataFrame -uri

# %%
df.head(2)
# Out:
#    country         team  trophies
# 0    Spain  Real Madrid      15.0
# 1  England    Liverpool       6.0

# %%
merged_df = pd.concat([big_df, df])
merged_df.head()
# Out:
#    country            team  trophies
# 0    Italy        AC Milan       7.0
# 1  Germany  Bayern Munchen       6.0
# 0    Spain     Real Madrid      15.0
# 1  England       Liverpool       6.0
# 2    Spain       Barcelona       5.0

# %% [markdown]
# # Sortare dupa mai multe criterii

# %%
# In ordinea celor mai multe trofee, apoi alfabetic dupa tara
merged_df.sort_values(["trophies", "country"], ascending=[False, True], inplace=True)

# %%
merged_df = merged_df.reset_index(drop=True)
merged_df
# Out:
#         country            team  trophies
# 0         Spain     Real Madrid      15.0
# 1         Italy        AC Milan       7.0
# 2       England       Liverpool       6.0
# 3       Germany  Bayern Munchen       6.0
# 4         Spain       Barcelona       5.0
# 5       England      Man United       3.0
# 6         Italy           Inter       3.0
# 7       England         Chelsea       2.0
# 8       England    Nottm Forest       2.0
# 9         Italy        Juventus       2.0
# 10     Portugal         Benfica       2.0
# 11     Portugal        FC Porto       2.0
# 12      England     Aston Villa       1.0
# 13      England        Man City       1.0
# 14       France       Marseille       1.0
# 15      Germany         Hamburg       1.0
# 16      Germany        Dortmund       1.0
# 17  Netherlands             PSV       1.0
# 18  Netherlands       Feyenoord       1.0
# 19     Scotland          Celtic       1.0
# 20       Serbia   Crvena zvezda       1.0
# ...

# %%
# 12. Găsiți toate echipele care au câștigat exact 2 trofee. 
merged_df[merged_df["trophies"] == 2]
# Out:
#      country          team  trophies
# 7    England       Chelsea       2.0
# 8    England  Nottm Forest       2.0
# 9      Italy      Juventus       2.0
# 10  Portugal       Benfica       2.0
# 11  Portugal      FC Porto       2.0

# %%
merged_df[merged_df.trophies == 2]
# Out:
#      country          team  trophies
# 7    England       Chelsea       2.0
# 8    England  Nottm Forest       2.0
# 9      Italy      Juventus       2.0
# 10  Portugal       Benfica       2.0
# 11  Portugal      FC Porto       2.0

# %%
# 13. Filtrați echipele în care țara este fie „Anglia”, fie „Italia”. 
merged_df[(merged_df.country == "England") | (merged_df.country == "Italy")]
# Out:
#     country          team  trophies
# 1     Italy      AC Milan       7.0
# 2   England     Liverpool       6.0
# 5   England    Man United       3.0
# 6     Italy         Inter       3.0
# 7   England       Chelsea       2.0
# 8   England  Nottm Forest       2.0
# 9     Italy      Juventus       2.0
# 12  England   Aston Villa       1.0
# 13  England      Man City       1.0

# %% [markdown]
# # # SAU logic este "|"

# %%
merged_df[merged_df.country.isin(["Italy", "England"])]
# Out:
#     country          team  trophies
# 1     Italy      AC Milan       7.0
# 2   England     Liverpool       6.0
# 5   England    Man United       3.0
# 6     Italy         Inter       3.0
# 7   England       Chelsea       2.0
# 8   England  Nottm Forest       2.0
# 9     Italy      Juventus       2.0
# 12  England   Aston Villa       1.0
# 13  England      Man City       1.0

# %% [markdown]
# # ȘI logic este "&"

# %%
# 14. Selectează echipele care au mai mult de 2 dar mai puțin de 7 trofee.

merged_df[(merged_df.trophies > 2) & (merged_df.trophies < 7)]
# Out:
#    country            team  trophies
# 2  England       Liverpool       6.0
# 3  Germany  Bayern Munchen       6.0
# 4    Spain       Barcelona       5.0
# 5  England      Man United       3.0
# 6    Italy           Inter       3.0

# %%
merged_df[merged_df.trophies.isin(range(3,7))]
# Out:
#    country            team  trophies
# 2  England       Liverpool       6.0
# 3  Germany  Bayern Munchen       6.0
# 4    Spain       Barcelona       5.0
# 5  England      Man United       3.0
# 6    Italy           Inter       3.0

# %%
# 15. Concatenati un nou DataFrame cu Manchester City și PSG cu 1 trofeu.
inter_winners =  pd.DataFrame([["England", "Manchester City", 1], ["France", "PSG", 1]], columns=df.keys())
inter_winners
# Out:
#    country             team  trophies
# 0  England  Manchester City         1
# 1   France              PSG         1

# %%
merged_df = pd.concat([merged_df, inter_winners])
merged_df
# Out:
#         country             team  trophies
# 0         Spain      Real Madrid      15.0
# 1         Italy         AC Milan       7.0
# 2       England        Liverpool       6.0
# 3       Germany   Bayern Munchen       6.0
# 4         Spain        Barcelona       5.0
# 5       England       Man United       3.0
# 6         Italy            Inter       3.0
# 7       England          Chelsea       2.0
# 8       England     Nottm Forest       2.0
# 9         Italy         Juventus       2.0
# 10     Portugal          Benfica       2.0
# 11     Portugal         FC Porto       2.0
# 12      England      Aston Villa       1.0
# 13      England         Man City       1.0
# 14       France        Marseille       1.0
# 15      Germany          Hamburg       1.0
# 16      Germany         Dortmund       1.0
# 17  Netherlands              PSV       1.0
# 18  Netherlands        Feyenoord       1.0
# 19     Scotland           Celtic       1.0
# 20       Serbia    Crvena zvezda       1.0
# ...

# %%
# 17. Editați intrarea FCSB în Steaua și nr de trofee aferent.
merged_df[merged_df["team"] == "FCSB"]
# Out:
#     country  team  trophies
# 21  Romania  FCSB       NaN

# %% [markdown]
# # Loc vs iLOC -> iloc este folosit pentru index, iar loc este pentru chei(string)

# %%
merged_df.loc[merged_df["team"] == "FCSB", ["team", "trophies"]] = ["Steaua", 1]

# %%
merged_df.loc[merged_df["country"] == "Netherlands"]
# Out:
#         country       team  trophies
# 17  Netherlands        PSV       1.0
# 18  Netherlands  Feyenoord       1.0

# %%
merged_df.loc[merged_df["country"] == "Netherlands", "country"] = "Netherlands"
merged_df
# Out:
#         country             team  trophies
# 0         Spain      Real Madrid      15.0
# 1         Italy         AC Milan       7.0
# 2       England        Liverpool       6.0
# 3       Germany   Bayern Munchen       6.0
# 4         Spain        Barcelona       5.0
# 5       England       Man United       3.0
# 6         Italy            Inter       3.0
# 7       England          Chelsea       2.0
# 8       England     Nottm Forest       2.0
# 9         Italy         Juventus       2.0
# 10     Portugal          Benfica       2.0
# 11     Portugal         FC Porto       2.0
# 12      England      Aston Villa       1.0
# 13      England         Man City       1.0
# 14       France        Marseille       1.0
# 15      Germany          Hamburg       1.0
# 16      Germany         Dortmund       1.0
# 17  Netherlands              PSV       1.0
# 18  Netherlands        Feyenoord       1.0
# 19     Scotland           Celtic       1.0
# 20       Serbia    Crvena zvezda       1.0
# ...

# %%
merged_df.reset_index(drop=True, inplace=True)
merged_df
# Out:
#         country             team  trophies
# 0         Spain      Real Madrid      15.0
# 1         Italy         AC Milan       7.0
# 2       England        Liverpool       6.0
# 3       Germany   Bayern Munchen       6.0
# 4         Spain        Barcelona       5.0
# 5       England       Man United       3.0
# 6         Italy            Inter       3.0
# 7       England          Chelsea       2.0
# 8       England     Nottm Forest       2.0
# 9         Italy         Juventus       2.0
# 10     Portugal          Benfica       2.0
# 11     Portugal         FC Porto       2.0
# 12      England      Aston Villa       1.0
# 13      England         Man City       1.0
# 14       France        Marseille       1.0
# 15      Germany          Hamburg       1.0
# 16      Germany         Dortmund       1.0
# 17  Netherlands              PSV       1.0
# 18  Netherlands        Feyenoord       1.0
# 19     Scotland           Celtic       1.0
# 20       Serbia    Crvena zvezda       1.0
# ...

# %%
# 18. Adaugati la final Ajax Amsterdam cu 4 trofee
merged_df.loc[24] = ["Netherlands", "Ajax Amsterdam", 4]
merged_df
# Out:
#         country             team  trophies
# 0         Spain      Real Madrid      15.0
# 1         Italy         AC Milan       7.0
# 2       England        Liverpool       6.0
# 3       Germany   Bayern Munchen       6.0
# 4         Spain        Barcelona       5.0
# 5       England       Man United       3.0
# 6         Italy            Inter       3.0
# 7       England          Chelsea       2.0
# 8       England     Nottm Forest       2.0
# 9         Italy         Juventus       2.0
# 10     Portugal          Benfica       2.0
# 11     Portugal         FC Porto       2.0
# 12      England      Aston Villa       1.0
# 13      England         Man City       1.0
# 14       France        Marseille       1.0
# 15      Germany          Hamburg       1.0
# 16      Germany         Dortmund       1.0
# 17  Netherlands              PSV       1.0
# 18  Netherlands        Feyenoord       1.0
# 19     Scotland           Celtic       1.0
# 20       Serbia    Crvena zvezda       1.0
# ...

# %%
# 19. Sortati, reindexati tot df si salvati-l intr-un nou csv 
merged_df = merged_df.sort_values(["trophies", "country"], ascending=(False, True)).reset_index(drop=True)
merged_df
# Out:
#         country             team  trophies
# 0         Spain      Real Madrid      15.0
# 1         Italy         AC Milan       7.0
# 2       England        Liverpool       6.0
# 3       Germany   Bayern Munchen       6.0
# 4         Spain        Barcelona       5.0
# 5   Netherlands   Ajax Amsterdam       4.0
# 6       England       Man United       3.0
# 7         Italy            Inter       3.0
# 8       England          Chelsea       2.0
# 9       England     Nottm Forest       2.0
# 10        Italy         Juventus       2.0
# 11     Portugal          Benfica       2.0
# 12     Portugal         FC Porto       2.0
# 13      England      Aston Villa       1.0
# 14      England         Man City       1.0
# 15      England  Manchester City       1.0
# 16       France        Marseille       1.0
# 17       France              PSG       1.0
# 18      Germany          Hamburg       1.0
# 19      Germany         Dortmund       1.0
# 20  Netherlands              PSV       1.0
# ...

# %%
merged_df.to_csv("echipe_polișate.csv")

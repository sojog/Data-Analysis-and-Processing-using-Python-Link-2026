# %%
o_lista = [3, 1, 5, 10, 8, 11]

# %% [markdown]
# # 1. Sortare cu "new value"

# %%
sorted(o_lista)
# Out:
# [1, 3, 5, 8, 10, 11]

# %% [markdown]
# ## Lista initiala ramane nesortata

# %%
o_lista
# Out:
# [3, 1, 5, 10, 8, 11]

# %% [markdown]
# # 2. In place

# %%
o_lista.sort()

# %% [markdown]
# # Ulterior lista initiala este sortata

# %%
o_lista
# Out:
# [1, 3, 5, 8, 10, 11]

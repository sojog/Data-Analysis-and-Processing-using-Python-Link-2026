# %% [markdown]
# # pip install pyperclip

# %%
from  pyperclip import copy

# %%
INSTALARE_DJANGO_CMD = "pip install django"
copy(INSTALARE_DJANGO_CMD)

# %%
PROJECT_NAME = "matematica"
START_PROJECT_CMD = "django-admin startproject " + PROJECT_NAME
copy(START_PROJECT_CMD)

# %%
ENTER_PROJECT_PATH = "cd " + PROJECT_NAME
copy(ENTER_PROJECT_PATH)

# %%
RUN_PROJECT_CMD = "python manage.py runserver"
copy(RUN_PROJECT_CMD)

# %% [markdown]
# # Deschide un nou terminal

# %%
ENTER_PROJECT_PATH = "cd " + PROJECT_NAME
copy(ENTER_PROJECT_PATH)

# %%
APP_NAME = "factorial"

CREATE_APP_CMD = "python manage.py startapp " + APP_NAME
copy(CREATE_APP_CMD)

# %%
bin(2)
# Out:
# '0b10'

# %%
for i in range(17):
    print("i=", i, "in baza 2 = ", bin(i)[2:])
# Out:
# i= 0 in baza 2 =  0
# i= 1 in baza 2 =  1
# i= 2 in baza 2 =  10
# i= 3 in baza 2 =  11
# i= 4 in baza 2 =  100
# i= 5 in baza 2 =  101
# i= 6 in baza 2 =  110
# i= 7 in baza 2 =  111
# i= 8 in baza 2 =  1000
# i= 9 in baza 2 =  1001
# i= 10 in baza 2 =  1010
# i= 11 in baza 2 =  1011
# i= 12 in baza 2 =  1100
# i= 13 in baza 2 =  1101
# i= 14 in baza 2 =  1110
# i= 15 in baza 2 =  1111
# i= 16 in baza 2 =  10000

# %% [markdown]
# # 8 bits = 1 byte (octet)

# %%
'11111111'

# %%
bin(2 ** 8 - 1)
# Out:
# '0b11111111'

# %%
2 ** 8 - 1
# Out:
# 255

# %% [markdown]
# # Operatii pe bits

# %%
2 ** 2
# Out:
# 4

# %%
bin(4)
# Out:
# '0b100'

# %%
bin(2 ** 3)
# Out:
# '0b1000'

# %%
x = 4

# %%
x = 0b1000
x
# Out:
# 8

# %%
x << 1
# Out:
# 16

# %%
x = 0b10000
x
# Out:
# 16

# %%
x << 2
# Out:
# 32

# %%
x = 10
print(bin(x))
# Out:
# 0b1010

# %%
0b101
# Out:
# 5

# %%
0b1010100
# Out:
# 84

# %%
0b101010
# Out:
# 42

# %%
0b10101
# Out:
# 21

# %%
0b1010
# Out:
# 10

# %%
0b101
# Out:
# 5

# %%
0b1010100
# Out:
# 84

# %%
0b10101000
# Out:
# 168

# %%
0b101010000
# Out:
# 336

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
BLUE = np.array([0, 43, 127])
YELLOW = np.array([252, 209, 22])
RED = np.array([206, 17, 38])

# %%
SCALE = 1 * 100

WIDTH = 15 * SCALE
HEIGHT = 9 * SCALE

# %%
steag_arr = np.ones((HEIGHT, WIDTH, 4), dtype=np.uint8)

# %%
steag_arr[:,:,-1] = 255
steag_arr
# Out:
# array([[[  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         ...,
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255]],
#
#        [[  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         ...,
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255]],
#
#        [[  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         ...,
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255]],
#
#        ...,
#
#        [[  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         ...,
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255]],
#
#        [[  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         [  1,   1,   1, 255],
#         ...,
#         [  1,   1,   1, 255],
# ...

# %%
new_image = Image.fromarray(steag_arr)
new_image.save("steag_negru.png")

# %%
steag_arr.shape
# Out:
# (900, 1500, 4)

# %%
WIDTH
# Out:
# 1500

# %%
WIDTH // 3
# Out:
# 500

# %%
steag_arr[:,0:WIDTH // 3, :3 ] = BLUE

# %%
steag_arr[:, WIDTH // 3 : 2 * WIDTH // 3, :3 ] = YELLOW

# %%
steag_arr[:,  2 * WIDTH // 3 : , :3 ] = RED

# %%
new_image = Image.fromarray(steag_arr)
new_image.save("steag_romania.png")
